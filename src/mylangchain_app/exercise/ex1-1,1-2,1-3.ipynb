# %%
# .env 파일에서 환경 변수를 불러오기 위한 라이브러리
from dotenv import load_dotenv
import os

# .env 파일의 경로를 지정하여 환경 변수를 로드합니다.
load_dotenv(dotenv_path='../.env')

# 환경 변수에서 OpenAI API 키를 가져옵니다.
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ### 문제 1-1: 기본 Chain 만들기 - AI 요리사

# %%
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser


# ChatOpenAI 모델을 초기화합니다.
llm = ChatOpenAI(
    api_key=OPENAI_API_KEY,
    base_url="https://api.groq.com/openai/v1",
    model="openai/gpt-oss-120b",
    temperature=0.7
)

# 프롬프트 템플릿을 정의합니다. 
# 이 템플릿은 사용자로부터 재료를 입력받아 AI에게 요리 추천을 요청하는 역할을 합니다.
# 프롬프트 템플릿을 수정하여 예상 실행 결과와 동일한 형식을 갖도록 합니다.
template_text = """
당신은 요리사입니다. 사용자가 제공하는 재료를 사용하여 만들 수 있는 요리법을 아래 형식에 맞춰 추천해주세요.

---
[입력 재료]: {ingredients}
---
[출력 형식]:{ingredients}로 만들 수 있는 요리를 추천드립니다!

추천 요리: [요리 이름]
재료: {ingredients}
조리법:
"""

# PromptTemplate.from_template() 함수를 사용하여 프롬프트 템플릿 객체를 생성합니다.
prompt_template = PromptTemplate.from_template(template_text)

# StrOutputParser를 사용하여 모델의 출력 결과를 문자열로 변환합니다.
output_parser = StrOutputParser()

# LCEL(LangChain Expression Language)을 사용하여 프롬프트, 모델, 출력 파서를 연결하는 체인을 생성합니다.
chain = prompt_template | llm | output_parser

# 1. 재료를 변수에 저장합니다.
ingredients = "계란, 밥, 김치"

# 체인을 실행하고 결과를 출력합니다.
# 'ingredients' 변수에 "계란, 밥, 김치"를 전달하여 체인을 호출합니다.
response = chain.invoke({"ingredients": ingredients})

# 최종 결과를 출력합니다.
print(f'입력: "{ingredients}"')
print("출력:")
print(response)
# Out:
# 입력: "계란, 밥, 김치"
# 출력:
# 계란, 밥, 김치로 만들 수 있는 요리를 추천드립니다!
#
# 추천 요리: 김치볶음밥 (계란 토핑)
# 재료: 계란, 밥, 김치
# 조리법:
# 1. **재료 준비**
#    - 김치를 작게 썰어 둡니다.
#    - 밥은 찬밥이 좋으며, 전날 남은 밥을 사용하면 더욱 고슬고슬합니다.
#    - 계란은 반숙 혹은 반숙 위에 올릴 경우 노른자를 살짝 풀어 둡니다.
#
# 2. **김치 볶기**
#    - 팬에 식용유(또는 참기름) 1큰술을 두르고 중불에서 달군다.
#    - 다진 마늘 1/2작은술을 넣고 향이 올라올 때까지 볶는다.
#    - 썰어 둔 김치를 넣고 3~4분간 중간 불에서 볶아 김치가 부드러워지고 약간 물기가 날아갈 때까지 볶는다.
#
# 3. **밥 넣기**
#    - 김치가 충분히 볶아졌으면 밥을 한 공기 넣고 고루 섞는다.
#    - 간장 1작은술, 고춧가루 1작은술, 설탕 ½작은술, 참기름 1작은술을 넣고 다시 한 번 골고루 볶아준다.
#    - 필요에 따라 소금·후추로 간을 맞춘다.
#
# 4. **계란 프라이**
#    - 다른 팬에 식용유를 살짝 두르고 중불에서 달군 뒤, 계란을 깨뜨려 넣는다.
#    - 흰자가 반쯤 익을 때까지 기다린 뒤, 노른자를 살짝 터뜨려 반숙 상태로 마무리한다. (노른자를 완전히 익히고 싶다면 완전히 익혀도 좋다.)
#
# 5. **플레이팅**
#    - 볶은 김치밥을 그릇에 담고, 그 위에 프라이한 계란을 올린다.
#    - 원한다면 김가루, 파썰기, 김치 조각을 고명으로 올려 색감과 풍미를 더한다.
#
# 6. **완성**
#    - 따뜻한 김치볶음밥 위에 부드러운 계란 노른자가 흐르며, 매콤한 김치와 고소한 밥, 부드러운 계란이 어우러진 한 끼가 완성됩니다. 즐겁게 드세요!

# %% [markdown]
# ### 문제 1-2 : 2단계 Multi Chain 만들기 - 여행지 정보 시스템

# %%
# 필요한 라이브러리들을 가져옵니다.
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnableParallel

# 1단계 체인: 여행지의 대표 명소 추천
prompt1 = ChatPromptTemplate.from_messages([
    ("system", "당신은 특정 도시나 국가의 대표적인 관광 명소 1가지를 추천하는 여행 전문가입니다."),
    ("user", "{topic}의 대표적인 관광 명소 1가지를 추천해주세요. 명소의 이름만 간결하게 답변해주세요.")
])

chain1 = prompt1 | llm | StrOutputParser()


# 2단계 체인: 명소의 상세 정보 제공
prompt2 = ChatPromptTemplate.from_messages([
    ("system", "당신은 특정 관광 명소에 대한 상세 정보를 제공하는 역사학자이자 여행 가이드입니다."),
    ("user", "{landmark}에 대한 상세한 정보를 역사, 특징, 방문 팁을 포함하여 설명해주세요.")
])

chain2 = prompt2 | llm | StrOutputParser()


# 두 체인을 연결하여 전체 체인 생성
# RunnableParallel을 사용하여 각 단계를 동시에 실행하고 결과를 함께 볼 수 있도록 구성합니다.
# 1. 'landmark' 키에는 chain1의 결과(명소 이름)를 할당합니다.
# 2. 'details' 키에는 chain1의 결과를 받아 chain2로 전달하여 상세 정보를 가져옵니다.
final_chain = RunnableParallel(
    landmark=chain1,
    details=chain1 | chain2
)

# 체인 실행
input_city = "프랑스"
result = final_chain.invoke({"topic": input_city})

# 결과 출력
print(f'입력: "{input_city}"')
print("-" * 30)
print(f'1단계 결과: "{result["landmark"]}"')
print("-" * 30)
print(f'2단계 결과:\n명소: {result["landmark"]}\n{result["details"]}')
# Out:
# 입력: "프랑스"
# ------------------------------
# 1단계 결과: "에펠탑"
# ------------------------------
# 2단계 결과:
# 명소: 에펠탑
# ## 에펠탑 (Eiffel Tower) – 역사·특징·방문 팁 종합 안내
#
# ---
#
# ### Ⅰ. 역사
#
# | 연도 | 주요 사건 | 의미·배경 |
# |------|-----------|-----------|
# | **1884년 1월** | 구스타프 에펠(​Gustave Eiffel)과 그의 엔지니어 팀이 파리 시청으로부터 **제2차 세계 박람회(Exposition Universelle, 1889)** 를 위한 설계 의뢰를 받음 | 파리 100주년을 기념하고, 당시 가장 높은 인공 구조물(300 m)을 만들겠다는 야심찬 목표가 제시됨 |
# | **1887년 1월** | 기초 공사 시작 (강철 기둥 18,038개, 무게 7,300 톤) | 파리 시민들의 반대와 “철의 괴물”이라는 비난에도 불구하고, 2년 2개월 만에 완공을 목표로 착공 |
# | **1889년 3월 31일** | **완공** 및 **시연 행사** (전등 점등, 엘리베이터 시연) | 41 일간 전시 기간 동안 2,000만 명 이상의 관람객이 방문, 당시 세계에서 가장 높은 구조물(324 m)로 기록 |
# | **1900년** | 제2차 파리 박람회에 재사용, 전기 조명 시스템 개선 | 전기 조명(2,000 개)으로 야경을 장식, ‘빛의 탑’이라는 별명이 붙음 |
# | **1910년** | **에펠탑 전용 전력망** 구축 (자체 발전소) | 전기 공급의 독립성을 확보해 파리 전력망에 큰 영향을 미침 |
# | **1937년** | 프랑스-독일 전쟁 전후, **전쟁 방어용 안테나** 설치 | 통신·라디오 전파 실험을 위한 전략적 활용 |
# | **1940~1944년** | **독일 점령** 시점에 전시관과 엘리베이터가 파손·폐쇄 | 전쟁 후 복구 작업을 거쳐 1946년 재개장 |
# | **1985년** | **에펠탑 100주년** 기념 대규모 리노베이션 (페인트 재도장, 구조 보강) | 20년마다 전체 외벽을 재도장(약 60톤의 페인트)해 부식 방지 |
# | **1999년** | **통신 안테나** 추가 설치, **디지털 방송** 전환 | 현재 2,000여 개의 안테나가 달려 전 세계에 프랑스 방송을 송출 |
# | **2024년** | **친환경 LED 조명** 교체, **에너지 절감** 및 **스마트 관광** 서비스 도입 | 지속 가능한 관광지 운영을 위한 최신 기술 적용 |
#
# > **핵심 포인트**
# > - 에펠탑은 단순한 전시용 구조물이 아니라 **산업·기술·문화 혁신의 상징**이며, 130년 넘는 세월 동안 **건축·전기·통신·관광** 등 다양한 분야에 영향을 미쳐 왔습니다.
#
# ---
#
# ### II. 특징
#
# | 구분 | 내용 | 상세 설명 |
# |------|------|-----------|
# | **구조·재료** | 철골 구조 (프랑스산 피라이트강) | 18,038개의 철골 부재와 2,500여 개의 리벳으로 조립, 무게 약 10,100 톤 |
# | **높이** | 324 m (안테나 포함) | 3층 전망대(166 m), 2개의 중간 플랫폼(115 m, 276 m) 등 3개의 관람 구역 |
# | **엘리베이터** | 2개 메인 엘리베이터·4개 보조 엘리베이터 | 최초에는 수동식 로프와 기계식 브레이크 사용, 현재는 최신 자동 제어 시스템 적용 |
# | **조명** | 20,000개 LED 라이트 + 5개의 파리시 광원 (광섬유) | 매일 저녁 9시부터 1분간 5분 간격으로 반짝이는 “빛의 쇼” (시즌에 따라 변동) |
# | **통신** | 라디오·TV·디지털 안테나 2,000여 개 | 세계에서 가장 많은 통신 안테나가 집결된 건축물 중 하나 |
# | **건축적 의미** | ‘**산업미학**’의 대표작 | 철골 구조를 미학적으로 재해석, ‘공기와 같은 건축물’이라는 에펠의 철학을 구현 |
# | **관람객 수** | 연간 약 7 백만 명 (COVID-19 전) | 전 세계 관광객이 가장 많이 찾는 랜드마크 중 하나 |
# | **문화·예술** | 영화·음악·패션·광고 등 다방면 활용 | 《라라랜드》, 《인셉션》 등 수많은 작품에 등장, 매년 수천 개의 사진·영상 촬영 허가 발급 |
#
# ---
#
# ### III. 방문 팁 (전문 가이드가 전하는 실전 노하우)
#
# #### 1. **예매·입장**
# | 항목 | 팁 |
# |------|----|
# | **온라인 예매** | 공식 웹사이트([toureiffel.paris](https://www.toureiffel.paris))에서 **시간대별 티켓**을 미리 구매 → 현장 대기시간 최소화 (성수기 30~60분 대기 → 5분 이내) |
# | **입장권 종류** | • **계단+엘리베이터** (1~2층) – 저렴하고 체력 도전 가능<br>• **전층 엘리베이터** – 편리하지만 가격 상승 (≈ 1.5배) |
# | **할인** | 12세 이하·학생·시니어(≥60세) 할인 + **Paris Pass** 보유 시 무료 입장 (우선 입장 라인 이용) |
# | **취소·환불** | 일정 변경 시 최소 24시간 전까지 온라인에서 전액 환불 가능 (특정 프로모션 제외) |
#
# #### 2. **베스트 타임**
# | 시기 | 특징 | 추천 이유 |
# |------|------|------------|
# | **오전 9시~10시** | 입장객이 가장 적음 | 라인 최소화, 사진 촬영 시 인파 적음 |
# | **일몰 직전 (17:30~18:30)** | 일몰과 야경을 동시에 감상 | 석양과 파리 시내 조명, “빛의 쇼” 직전 분위기 최고 |
# | **주중 (월~목)** | 주말 대비 30~40% 적은 방문객 | 업무 여행객 위주, 현지인 비율 높음 |
# | **비수기 (11월~3월)** | 날씨는 다소 추울 수 있지만 인파가 거의 없음 | 저렴한 항공·숙박, 에펠탑 내부 난방 잘 되어 있어 쾌적 |
#
# #### 3. **교통·이동**
# | 교통수단 | 상세 정보 |
# |----------|-----------|
# | **지하철** | **라인 6** ‘Bir­h‑Lemoine’ 역, **라인 9** ‘Trocadéro’ 역, **라인 1** ‘Charles de Gaulle – Étoile’ 역 (샤를드골 – 에투알)에서 도보 5~10분 |
# | **버스** | 82, 87, 92번 버스 (에펠탑 정류장) |
# | **RER** | RER C ‘Champ de Mars – Tour Eiffel’ 역 (도보 10분) |
# | **자전거·전동스쿠터** | ‘Velib’ 대여소 2곳 (Champ de Mars, Quai Branly) – 자전거 전용 도로 이용 권장 |
# | **주차** | 주변에 유료 주차장 3곳 (시내 중심가 대비 비싼 편) – 대중교통 이용이 가장 효율적 |
#
# #### 4. **현장 팁**
# | 상황 | 팁 |
# |------|----|
# | **줄 서기** | 1층 **입구**에 도착하면 **QR코드 스캔**을 바로 진행 → 입장 전 자동 검표 시스템으로 대기 시간 절감 |
# | **사진 촬영** | 1층 ‘샤를 드 골 광장’에서 **대칭 구도** (탑 중앙을 중심) 촬영이 가장 인상적<br>2층 ‘플라톤 전망대’에서는 **파노라마** (스마트폰 파노라믹 모드) 활용 |
# | **음식·음료** | 1층 ‘레 파리제’(레스토랑)와 2층 ‘라 메르시’(카페)에서 **프랑스식 크루아상·에스프레소**를 즐기면 에펠 전망과 함께 특별함 ↑<br>**음식 반입 금지** (보안상) |
# | **안전·보안** | 금속 탐지기 통과 필수, 가방은 **소형 백팩** 이하 권장 (대형 가방은 입구에서 보관소 이용) |
# | **특별 이벤트** | **‘빛의 쇼’**는 매일 저녁 9시(시즌에 따라 변동) 5분간 진행 → 앞쪽 플랫폼에서 관람하면 가장 가까운 거리에서 감상 가능 |
# | **아이·장애인** | 1층·2층 엘리베이터에 **유아용 유모차**와 **휠체어** 접근 가능, **무료 입장** (증명서 필요) |
#
# #### 5. **주변 명소와 연계 일정**
# | 명소 | 이동 시간 | 추천 코스 |
# |------|-----------|-----------|
# | **샤를 드 골 광장 (Champ de Mars)** | 도보 2분 | 탑 앞에서 피크닉·사진 촬영 |
# | **오르세 미술관 (Musée d’Orsay)** | 도보 15분 | 인상파 미술 감상 후 탑 전망과 비교 |
# | **세느강 유람선 (Bateaux‑Mouches)** | 도보 10분 (Port de la Bourdonnais) | 강 위에서 에펠탑 야경을 360° 감상 |
# | **루브르 박물관** | 메트로 1호선 15분 | 파리 전통 ‘3대 박물관 + 에펠탑’ 투어 |
# | **몽마르트 언덕 (Montmartre)** | 메트로 6호선 + 2호선 20분 | 파리 전경을 두 번 감상 (에펠·노틀담·사크레‑쾨르) |
#
# ---
#
# ### IV. 실용 정보 (한눈에 보는 체크리스트)
#
# | 항목 | 내용 |
# |------|------|
# | **영업시간** | 09:30 ~ 23:45 (시즌에 따라 변동, 겨울 23:00 종료) |
# | **입장료 (2025년 기준)** | • 1층·2층 엘리베이터: 성인 €26.10, 청소년(12‑24) €13.20, 어린이(4‑11) €6.60<br>• 전층 엘리베이터: 성인 €34.80, 청소년 €17.40, 어린이 €8.70 |
# | **환불 정책** | 24시간 전까지 전액 환불, 당일 취소 시 환불 불가 (예외: 기상 악화·공연 취소) |
# | **언어** | 프랑스어·영어·스페인어·독일어·중국어(간체·번체) 안내 표지판 및 오디오 가이드 제공 |
# | **보안** | 금속 탐지기, 가방 검열, 촬영 금지 구역(전력실·통신실) |
# | **편의시설** | • 1층·2층·3층에 각각 **화장실·수유실·장애인용 화장실**<br>• **무료 Wi‑Fi** (에펠탑 전용 SSID) |
# | **추천 복장** | 2025년 기준 **날씨에 맞는 겹겹이 입기** (봄·가을: 가벼운 재킷, 겨울: 방한복) – 탑 내부는 냉난방이 잘 되어 있어 온도 차에 대비 |
# | **기념품** | 1층 ‘Boutique Eiffel Tower’에서 **미니어처, 포스터, 향수, 와인** 등 다양한 프랑스 기념품 구입 가능 |
#
# ---
#
# ## 📌 한 줄 요약
#
# > **에펠탑은 130년 역사를 품은 ‘산업미학’의 걸작**이며, **시간대·티켓 종류·교통**를 미리 계획하면 **짧은 대기 시간에 파리 최고의 파노라마와 빛의 쇼**를 즐길 수 있습니다.
#
# ---
#
# ### 📅 3일 파리 일정에 에펠탑을 포함한 샘플 일정
#
# | 시간 | 일정 |
# |------|------|
# | **08:30** | 호텔 조식 후 **샤틀버스**(또는 지하철 6호선) 탑승 |
# | **09:30** | **에펠탑 1층·2층 엘리베이터** (예매한 시간대) – 전망·사진 촬영 |
# | **11:00** | **세느강 유람선** 탑승 (Bateaux‑Mouches) – 강 위에서 파리 전경 |
# | **12:30** | **샤를 드 골 광장**에서 피크닉(크루아상·샤퀴테리) |
# | **14:00** | **오르세 미술관** 관람 (15분 도보) |
# | **17:00** | **에펠탑 3층** (전층 엘리베이터) – 일몰 감상 |
# | **19:30** | **빛의 쇼** (9시) 전후에 3층에서 야경 감상 |
# | **20:30** | 주변 레스토랑(‘Le Jules Verne’ 등)에서 저녁 식사 |
# | **22:30** | 호텔 복귀 혹은 **세느강 야경 산책** 마무리 |
#
# ---
#
# > **추가 문의**가 있으면 언제든 알려 주세요! 예산·숙소·맞춤 일정 등 세부적인 여행 플랜도 도와드릴게요. 즐거운 파리 여행 되시길 바랍니다! 🚀✨

# %% [markdown]
# ### 문제 1-3 : FewShotPromptTemplate과 시스템 메시지 활용

# %%
# 필요한 라이브러리들을 가져옵니다.
from langchain_openai import ChatOpenAI
from langchain_core.prompts import (
    FewShotChatMessagePromptTemplate,
    ChatPromptTemplate,
)
from langchain_core.output_parsers import StrOutputParser

# 1. Few-Shot 학습을 위한 예시 데이터 정의
examples = [
    {
        "news": "삼성전자가 내년 초에 자체적으로 개발한 인공지능(AI) 가속기를 처음으로 출시할 예정이다. 이는 AI 반도체 시장에서 지배적인 위치를 차지하고 있는 엔비디아의 독점을 도전하고, 세계 최고의 반도체 제조업체로서의 지위를 다시 확립하려는 삼성전자의 노력으로 해석된다.",
        "keywords": "삼성전자, 인공지능, 엔비디아"
    },
    {
        "news": "세계보건기구(WHO)는 최근 새로운 건강 위기에 대응하기 위해 국제 협력의 중요성을 강조했다. 전염병 대응 역량의 강화와 글로벌 보건 시스템의 개선이 필요하다고 발표했다.",
        "keywords": "세계보건기구, 건강 위기, 국제 협력"
    },
    {
        "news": "영화 '범죄도시4'가 개봉 10일 만에 천만 관객을 돌파하며 흥행 신기록을 세웠다. 주연 배우 마동석의 시원한 액션 연기가 관객들의 큰 호응을 얻고 있다.",
        "keywords": "범죄도시4, 천만 관객, 마동석"
    }
]

# 2. 각 예시의 형식을 정의하는 프롬프트 템플릿 생성
# 사용자의 뉴스 기사({news})와 AI의 답변({keywords}) 형식을 지정합니다.
example_prompt = ChatPromptTemplate.from_messages([
    ("human", "{news}"),
    ("ai", "키워드: {keywords}")
])

# 3. Few-Shot 프롬프트 템플릿 생성
# 위에서 정의한 예시 데이터와 형식 템플릿을 결합합니다.
few_shot_prompt = FewShotChatMessagePromptTemplate(
    example_prompt=example_prompt,
    examples=examples,
)

# 4. 최종 프롬프트 템플릿 생성
# 시스템 메시지, Few-Shot 예시, 그리고 실제 사용자 입력을 모두 포함하는 최종 프롬프트를 만듭니다.
final_prompt = ChatPromptTemplate.from_messages([
    ("system", "당신은 뉴스 기사의 핵심 키워드 3개를 정확하게 추출하는 AI 전문가입니다. '키워드: ' 형식으로 답변해주세요."),
    few_shot_prompt,  # AI에게 학습시킬 예시들을 여기에 삽입합니다.
    ("human", "{input}")   # 실제 분석을 요청할 뉴스 기사가 들어갈 자리입니다.
])


# 5. 체인 생성 및 실행
chain = final_prompt | llm | StrOutputParser()

test_news = "제미나이 2.0 플래시는 현재 구글 AI 스튜디오(Google AI Studio) 및 버텍스 AI(Vertex AI)에서 제미나이 API를 통해 개발자에게 실험 모델로 제공됩니다. 모든 개발자는 멀티모달 입력 및 텍스트 출력을 사용할 수 있으며, 텍스트 음성 변환(text-to-speech) 및 네이티브 이미지 생성은 일부 파트너들을 대상으로 제공됩니다. 내년 1월에는 더 많은 모델 사이즈와 함께 일반에 공개될 예정입니다."

result = chain.invoke({"input": test_news})

# 결과 출력
print(f"입력 뉴스:\n{test_news}")
print("-" * 30)
print(f"추출 결과:\n{result}")
# Out:
# 입력 뉴스:
# 제미나이 2.0 플래시는 현재 구글 AI 스튜디오(Google AI Studio) 및 버텍스 AI(Vertex AI)에서 제미나이 API를 통해 개발자에게 실험 모델로 제공됩니다. 모든 개발자는 멀티모달 입력 및 텍스트 출력을 사용할 수 있으며, 텍스트 음성 변환(text-to-speech) 및 네이티브 이미지 생성은 일부 파트너들을 대상으로 제공됩니다. 내년 1월에는 더 많은 모델 사이즈와 함께 일반에 공개될 예정입니다.
# ------------------------------
# 추출 결과:
# 키워드: 제미나이 2.0, 구글 AI 스튜디오, 멀티모달 입력/출력
